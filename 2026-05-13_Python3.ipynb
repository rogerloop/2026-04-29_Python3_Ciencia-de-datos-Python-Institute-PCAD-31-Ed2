# %%
# 0. Importar las librerias necesarias
import pandas as pd

# 1. Ajustar la ruta del fichero excel

ruta_csv = "/Users/rogerdefez/Documents/Cursos i Llibres/Curso Barcelona Activa/2026-04-29_Python3_Ciencia-de-datos-Python-Institute-PCAD-31-Ed2/Datos_originales/PAISESTOP10.csv"

# 2. Cargar el DataFrame excel con los datos
pedidos_agrupados_top10 = pd.read_csv(ruta_csv)

# Para usar matplotlib debo instalar la libreria externa, desde terminal pip install matplotlib


# 0. llamar a la libreria y a la clase

import matplotlib.pyplot as plt

# 1. Para crear un grafico debo reservar espacio en el kernel con figure

plt.figure(figsize=(12,6))

# 2. Crear el gráfico de columnas tipo break , kind = 'bar'

pedidos_agrupados_top10.plot(kind='bar', x='PaísDestinatario', y='Importe', color='orange')

# 3. Ajustar parametros del grafico
plt.title("Top 10 - Importes por pais")          # Titulo del grafico
plt.xlabel("Paises")                            # Titulo eje x  
plt.ylabel("Suma Importe")                      # Titulo eje y  
plt.legend()
plt.xticks(rotation=45)                         # rota el titulo eje x 45º



# 3. Llamada al grafico.  plt.show()
plt.show()

# %%
# 0. Importar las librerias necesarias
import pandas as pd

# 1. Ajustar la ruta del fichero excel

ruta_csv = "/Users/rogerdefez/Documents/Cursos i Llibres/Curso Barcelona Activa/2026-04-29_Python3_Ciencia-de-datos-Python-Institute-PCAD-31-Ed2/Datos_originales/pedidoscategoria.csv"

# 2. Cargar el DataFrame excel con los datos
pedidos_agrupados_top10 = pd.read_csv(ruta_csv)


# Para usar matplotlib debo instalar la libreria externa, desde terminal pip install matplotlib


# 0. llamar a la libreria y a la clase

import matplotlib.pyplot as plt

# 1. Para crear un grafico debo reservar espacio en el kernel con figure

plt.figure(figsize=(12,6))

# 2. Crear el gráfico de columnas tipo break , kind = 'bar'

pedidos_agrupados_top10.plot(kind='bar', x='NombreCategoría', y='num_pedios', color='violet')

# 3. Ajustar parametros del grafico
plt.title("Top 10 - Importes por pais")          # Titulo del grafico
plt.xlabel("Paises")                            # Titulo eje x  
plt.ylabel("Suma Importe")                      # Titulo eje y  
plt.legend()
plt.xticks(rotation=45)                         # rota el titulo eje x 45º



# 3. Llamada al grafico.  plt.show()
plt.show()

# %%
# 0. Importar las librerias necesarias
import pandas as pd

# 1. Ajustar la ruta del fichero excel

ruta_csv = "/Users/rogerdefez/Documents/Cursos i Llibres/Curso Barcelona Activa/2026-04-29_Python3_Ciencia-de-datos-Python-Institute-PCAD-31-Ed2/Datos_originales/3paises.csv"

# 2. Cargar el DataFrame excel con los datos
pedidos_agrupados_top3 = pd.read_csv(ruta_csv)

# Para usar matplotlib debo instalar la libreria externa, desde terminal pip install matplotlib


# 0. llamar a la libreria y a la clase

import matplotlib.pyplot as plt

# 1. Para crear un grafico debo reservar espacio en el kernel con figure

plt.figure(figsize=(12,6))

# 2. Crear el gráfico de columnas tipo break , kind = 'bar'

pedidos_agrupados_top3.plot(kind='bar', x='PaísDestinatario', y='Importe', color='green')

# 3. Ajustar parametros del grafico
plt.title("3Paises - Importes por pais")          # Titulo del grafico
plt.xlabel("Paises")                            # Titulo eje x  
plt.ylabel("Suma Importe")                      # Titulo eje y  
plt.legend()
plt.xticks(rotation=45)                         # rota el titulo eje x 45º



# 3. Llamada al grafico.  plt.show()
plt.show()
